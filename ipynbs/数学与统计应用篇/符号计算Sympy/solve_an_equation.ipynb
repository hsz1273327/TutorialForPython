# %% [markdown]
# # 解方程
#
# 和计算算式不同,解方程是知道结果求变量,作为符号运算工具,sympy在解方程方面非常直观

# %%
from sympy import symbols,init_printing
x, y, z = symbols('x y z')
init_printing(use_unicode=True)

# %% [markdown]
# ## 相等
#
# python中`=`是赋值,`==`是判断相等,因此
# sympy中使用函数`Eq(exp1,exp2)`来表示两个算式相等

# %%
from sympy import Eq

# %%
Eq(x,y)
# Out:
# x = y

# %% [markdown]
# 求解方程使用`solveset(Eq(expr, result), var)`来求解方程

# %%
from sympy import solveset

# %%
solveset(Eq(x**2, 1), x)
# Out:
# {-1, 1}

# %% [markdown]
# 因为就一个参数所以x可以省略

# %%
solveset(Eq(x**2, 1))
# Out:
# {-1, 1}

# %% [markdown]
# 如果第一个参数不是等式,那么默认的`solveset`将会把它作为等于0处理
# `solveset(expr, var)`

# %%
solveset(x**2-1, x)
# Out:
# {-1, 1}

# %% [markdown]
# 其实`solveset(equation, variable=None, domain=S.Complexes)`才是solveset的完整接口,而domain则表示域

# %%
from sympy import S,sin,cos,exp

# %%
solveset(x - x, x, domain=S.Reals)
# Out:
# ℝ

# %%
solveset(sin(x) - 1, x, domain=S.Reals)
# Out:
# ⎧        π        ⎫
# ⎨2⋅n⋅π + ─ | n ∊ ℤ⎬
# ⎩        2        ⎭

# %% [markdown]
# 如果无解,那么结果就是空

# %%
solveset(exp(x), x)     # No solution exists
# Out:
# ∅

# %%
solveset(cos(x) - x, x)
# Out:
# {x | x ∊ ℂ ∧ -x + cos(x) = 0}

# %% [markdown]
# ## 求方程组
#
# 求方程组可以用`linsolve(exps...,(vars...))`函数

# %%
from sympy import linsolve

# %%
linsolve([x + y + z - 1,
          x + y + 2*z - 3 ], (x, y, z))
# Out:
# {(-y - 1, y, 2)}

# %% [markdown]
# 当然也可以使用矩阵的方式,矩阵将在下一部分学习

# %%
from sympy import Matrix

# %%
A=Matrix([[1,1,1],[1,1,2]])

# %%
b = Matrix([[1],[3]])

# %%
linsolve((A,b,),(x,y,z,))
# Out:
# {(-y - 1, y, 2)}

# %% [markdown]
# ## 求解微分方程
#
# `dsolve()`是微分方程的求解函数

# %%
from sympy import Function,dsolve

# %%
f, g = symbols('f g', cls=Function)

# %%
f(x)
# Out:
# f(x)

# %%
f(x).diff(x)
# Out:
# d
# ──(f(x))
# dx

# %%
diffeq = Eq(f(x).diff(x, x) - 2*f(x).diff(x) + f(x),
            sin(x))

# %%
diffeq
# Out:
#                       2
#          d           d
# f(x) - 2⋅──(f(x)) + ───(f(x)) = sin(x)
#          dx           2
#                     dx

# %%
dsolve(diffeq, f(x))
# Out:
#                     x   cos(x)
# f(x) = (C₁ + C₂⋅x)⋅ℯ  + ──────
#                           2

# %%
f(x).diff(x)*(1 - sin(f(x)))
# Out:
#                  d
# (-sin(f(x)) + 1)⋅──(f(x))
#                  dx

# %%
dsolve(f(x).diff(x)*(1 - sin(f(x))),
       f(x))
# Out:
# f(x) + cos(f(x)) = C₁
